# %%
# check if config exists
try:
    config
except NameError:
    config_exists = False
else:
    config_exists = True

# make config if it does not exist already (e.g. passed in by papermill)
if not(config_exists):
    # set up some config for the experiment run
    config = {
        "data_path" : "C:/Users/nico_/Desktop/ITBA/TFI/github/df_procesado/fixed_gear_fe.csv",
        "output_label": "trollers"
    }
config['data_path']="C:/Users/nico_/Desktop/ITBA/TFI/github/df_procesado/purse_seines_fe.csv"
print(config)
# Out:
# {'data_path': 'C:/Users/nico_/Desktop/ITBA/TFI/github/df_procesado/trawlers_fe.csv', 'output_label': 'trollers'}

# %%
import pandas as pd

df = pd.read_csv(config['data_path'], header="infer", sep=",",error_bad_lines=False, engine ='python')
print(len(df[df['is_fishing']=='SI']))
original = df
# Out:
# 14038

# %%
df = original

def n_prior_to_condition(df, n, condition):
    groups = condition.iloc[::-1].cumsum()
    return df.groupby(groups).tail(n+1)[:15000]

for i in range(0,10000):
    aux = n_prior_to_condition(df, i, df.is_fishing=="SI")  
    aux = aux.drop_duplicates()
    yes = (len(aux[aux['is_fishing']=='SI']))
    no = (len(aux[aux['is_fishing']=='NO']))
    if (yes/no<=1):
        if (yes+no==15000) and yes < 6000 :
            print(f'{yes}/{no}/{i}')
            continue
        df=aux
        print(i)
        break
    print(f'{yes}/{no}/{i}')

print(len(df[df['is_fishing']=='SI']))
print((len(df[df['is_fishing']=='NO'])))
#df.to_csv(f"../../df_procesado/{config['output_label']}_fe_recortado.csv",sep=",",index=False)
# Out:
# 14038/1/0
# 8353/6647/1
# 5549/9451/2
# 4324/10676/3
# 3566/11434/4
# 3053/11947/5
# 2717/12283/6
# 2460/12540/7
# 2270/12730/8
# 2095/12905/9
# 1939/13061/10
# 1782/13218/11
# 1641/13359/12
# 1533/13467/13
# 1456/13544/14
# 1372/13628/15
# 1324/13676/16
# 1285/13715/17
# 1239/13761/18
# 1206/13794/19
# 1164/13836/20
# 1117/13883/21
# 1091/13909/22
# 1054/13946/23
# 1032/13968/24
# 1011/13989/25
# 987/14013/26
# 954/14046/27
# 939/14061/28
# 925/14075/29
# 915/14085/30
# 905/14095/31
# 893/14107/32
# 884/14116/33
# 872/14128/34
# 860/14140/35
# 851/14149/36
# 840/14160/37
# 834/14166/38
# 826/14174/39
# 815/14185/40
# 807/14193/41
# 800/14200/42
# 794/14206/43
# 788/14212/44
# 783/14217/45
# 777/14223/46
# 765/14235/47
# 754/14246/48
# 734/14266/49
# 717/14283/50
# 709/14291/51
# 704/14296/52
# 699/14301/53
# 695/14305/54
# 690/14310/55
# 687/14313/56
# 681/14319/57
# 677/14323/58
# 670/14330/59
# 666/14334/60
# 662/14338/61
# 655/14345/62
# 651/14349/63
# 647/14353/64
# 638/14362/65
# 635/14365/66
# 632/14368/67
# 629/14371/68
# 628/14372/69
# 626/14374/70
# 623/14377/71
# 622/14378/72
# 619/14381/73
# 617/14383/74
# 615/14385/75
# 611/14389/76
# 607/14393/77
# 606/14394/78
# 605/14395/79
# 603/14397/80
# 600/14400/81
# 598/14402/82
# 594/14406/83
# 588/14412/84
# 585/14415/85
# 580/14420/86
# 580/14420/87
# 577/14423/88
# 575/14425/89
# 574/14426/90
# 573/14427/91
# 572/14428/92
# 569/14431/93
# 564/14436/94
# 564/14436/95
# 562/14438/96
# 559/14441/97
# 558/14442/98
# 554/14446/99
# 552/14448/100
# 546/14454/101
# 546/14454/102
# 545/14455/103
# 544/14456/104
# 542/14458/105
# 542/14458/106
# 541/14459/107
# 541/14459/108
# 540/14460/109
# 540/14460/110
# 538/14462/111
# 538/14462/112
# 538/14462/113
# 537/14463/114
# 537/14463/115
# 536/14464/116
# 536/14464/117
# 535/14465/118
# 535/14465/119
# 533/14467/120
# 533/14467/121
# 532/14468/122
# 530/14470/123
# 527/14473/124
# 527/14473/125
# 527/14473/126
# 526/14474/127
# 524/14476/128
# 524/14476/129
# 524/14476/130
# 523/14477/131
# 521/14479/132
# 521/14479/133
# 521/14479/134
# 520/14480/135
# 519/14481/136
# 519/14481/137
# 519/14481/138
# 516/14484/139
# 514/14486/140
# 514/14486/141
# 514/14486/142
# 513/14487/143
# 512/14488/144
# 510/14490/145
# 510/14490/146
# 510/14490/147
# 510/14490/148
# 510/14490/149
# 508/14492/150
# 507/14493/151
# 507/14493/152
# 504/14496/153
# 503/14497/154
# 501/14499/155
# 501/14499/156
# 501/14499/157
# 501/14499/158
# 501/14499/159
# 501/14499/160
# 501/14499/161
# 498/14502/162
# 498/14502/163
# 498/14502/164
# 497/14503/165
# 497/14503/166
# 497/14503/167
# 496/14504/168
# 495/14505/169
# 495/14505/170
# 495/14505/171
# 495/14505/172
# 494/14506/173
# 494/14506/174
# 494/14506/175
# 493/14507/176
# 493/14507/177
# 492/14508/178
# 492/14508/179
# 492/14508/180
# 491/14509/181
# 491/14509/182
# 491/14509/183
# 491/14509/184
# 491/14509/185
# 491/14509/186
# 491/14509/187
# 491/14509/188
# 490/14510/189
# 489/14511/190
# 488/14512/191
# 488/14512/192
# 488/14512/193
# 488/14512/194
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-d113154e4ba9> in <module>
#       6
#       7 for i in range(0,10000):
# ----> 8     aux = n_prior_to_condition(df, i, df.is_fishing=="SI")
#       9     aux = aux.drop_duplicates()
#      10     yes = (len(aux[aux['is_fishing']=='SI']))
#
# <ipython-input-42-d113154e4ba9> in n_prior_to_condition(df, n, condition)
#       3 def n_prior_to_condition(df, n, condition):
#       4     groups = condition.iloc[::-1].cumsum()
# ----> 5     return df.groupby(groups).tail(n+1)[:15000]
#       6
#       7 for i in range(0,10000):
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     826         # allow us to passing the actual Grouping as the gpr
#     827         ping = (
# --> 828             Grouping(
#     829                 group_axis,
#     830                 gpr,
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis, dropna)
#     451         self.name = name
#     452         self.level = level
# --> 453         self.grouper = _convert_grouper(index, grouper)
#     454         self.all_grouper = None
#     455         self.index = index
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py in _convert_grouper(axis, grouper)
#     866             return grouper._values
#     867         else:
# --> 868             return grouper.reindex(axis)._values
#     869     elif isinstance(grouper, (list, Series, Index, np.ndarray)):
#     870         if len(grouper) != len(axis):
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    4343     )
#    4344     def reindex(self, index=None, **kwargs):
# -> 4345         return super().reindex(index=index, **kwargs)
#    4346
#    4347     def drop(
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4809
#    4810         # perform the reindex on the axes
# -> 4811         return self._reindex_axes(
#    4812             axes, level, limit, tolerance, method, fill_value, copy
#    4813         ).__finalize__(self, method="reindex")
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4825
#    4826             ax = self._get_axis(a)
# -> 4827             new_index, indexer = ax.reindex(
#    4828                 labels, level=level, limit=limit, tolerance=tolerance, method=method
#    4829             )
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\indexes\base.py in reindex(self, target, method, level, limit, tolerance)
#    3514             else:
#    3515                 if self._index_as_unique:
# -> 3516                     indexer = self.get_indexer(
#    3517                         target, method=method, limit=limit, tolerance=tolerance
#    3518                     )
#
# d:\Users\nico_\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_indexer(self, target, method, limit, tolerance)
#     381         if step != self.step:
#     382             # We reversed this range: transform to original locs
# --> 383             locs[valid] = len(self) - 1 - locs[valid]
#     384         return ensure_platform_int(locs)
#     385
#
# KeyboardInterrupt:

# %%
#print(df.count())
